# %%
# Bir kart destesini karıştırmak için Python programı
#  modülleri içe aktarma
import itertools, random
# kart destesi oluştur 
kalp="\033[91m♥\033[0m"
maça="\033[1m♠\033[0m"
karo="\033[91m♦\033[0m"
sinek="\033[1m♣\033[0m"
kart = list(itertools.product(range(1,6),[kalp, maça, karo, sinek]))
# Kartları karıştır
random.shuffle(kart)
# Karıştırılmış kartları yazdır
 
print("\033[1m\033[102mKartlarınız:\033[0m")
renklis=[]
sayılis=[]
for i in range(5):
    renklis.append(kart[i][1])
    sayılis.append(kart[i][0])
    print(i+1,".kart ", kart[i][1], kart[i][0] )
durum1=True
while durum1:   
    kartsayısı=input("kaç kart çıkaracaksınız")
    # Kullanıcının girdiği rakam ise True değilse False
    if kartsayısı.isdigit()==False:     
        print("sadece 0 dan 5 e kadar rakam girmelisiniz.")
        durum1=True
    else:
        kartsayısı=int(kartsayısı)
        if kartsayısı==0:
            durum2=False
            durum1=False
            print("değiştirilecek kart sayısı= ","yok")
        elif kartsayısı>=1 and kartsayısı<=5:
            durum2=True
            durum1=False
            print("değiştirilecek kart sayısı= ",kartsayısı)
        else:
            print("yanlızca 0,1,2,3,4 veya 5 kart değişikliği yapabilirsiniz")
            durum1=True
while durum2:
    sayaç=0
        # kart destesi oluştur 
    kart = list(itertools.product(range(1,5),[kalp, maça, karo, sinek]))
        # Kartları karıştır
    random.shuffle(kart)
    for i in range(kartsayısı):
        sayaç += 1
        print(sayaç,". değiştirilecek kart sıra no giriniz.")
        kno=int(input(""))
        index=kno-1
        renklis[index]=kart[i][1]
        sayılis[index]=kart[i][0]
    durum2=False
print("\033[1m\033[104mKartlarınız:\033[0m")
for i in range(0,5):
    print(i+1,".kart ", renklis[i],sayılis[i])
print("Oyun sonu")
